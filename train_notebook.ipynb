# %%
from ultralytics_custom import YOLO

# %%
# Load a model

data = r"C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\data.yaml"
single_cls = True
pretrained = True

model = YOLO(r'C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\configs\YOLO_V8_P0-P1.yaml')  # load yaml and start form scratch
# Train the model
model.train(
    name='yolov8s_1000ep_sgd', 
    data=data,
    pretrained=pretrained,
    epochs = 1,
    imgsz = 640,
    patience = 100,
    batch = 2, #auto batch size
    save_period = -1, #only save final checkpoint and best checkpoint
    optimizer = 'SGD',
    single_cls = single_cls,
    deterministic = False
    )

# Evaluate the model
model.val(
    data=data,
    batch=1,
    imgsz=640,
    conf=0.001,  # confidence threshold (default 0.001)
    iou=0.6,  # NMS IOU threshold (default 0.6)
    save_json=True,  # save a cocoapi-compatible JSON results file
    single_cls=single_cls,  # treat as single-class dataset
    deterministic = False
    )
# Out:
# WARNING  no model scale passed. Assuming scale='m'.
# WARNING WARNING  no model scale passed. Assuming scale='m'.
#                    from  n    params  module                                       arguments
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics_custom.nn.modules.Conv           [3, 48, 3, 2]
#   0                  -1  1      1392  ultralytics_custom.nn.modules.Conv           [3, 48, 3, 2]
#   1                  -1  1     16416  ultralytics_custom.nn.modules.C2f            [48, 48, 1, True]
#   1                  -1  1     16416  ultralytics_custom.nn.modules.C2f            [48, 48, 1, True]
#   2                  -1  1     41664  ultralytics_custom.nn.modules.Conv           [48, 96, 3, 2]
#   2                  -1  1     41664  ultralytics_custom.nn.modules.Conv           [48, 96, 3, 2]
#   3                  -1  2    111360  ultralytics_custom.nn.modules.C2f            [96, 96, 2, True]
#   3                  -1  2    111360  ultralytics_custom.nn.modules.C2f            [96, 96, 2, True]
#   4                  -1  1    166272  ultralytics_custom.nn.modules.Conv           [96, 192, 3, 2]
#   4                  -1  1    166272  ultralytics_custom.nn.modules.Conv           [96, 192, 3, 2]
#   5                  -1  4    813312  ultralytics_custom.nn.modules.C2f            [192, 192, 4, True]
#   5                  -1  4    813312  ultralytics_custom.nn.modules.C2f            [192, 192, 4, True]
#   6                  -1  1    664320  ultralytics_custom.nn.modules.Conv           [192, 384, 3, 2]
#   6                  -1  1    664320  ultralytics_custom.nn.modules.Conv           [192, 384, 3, 2]
#   7                  -1  4   3248640  ultralytics_custom.nn.modules.C2f            [384, 384, 4, True]
#   7                  -1  4   3248640  ultralytics_custom.nn.modules.C2f            [384, 384, 4, True]
#   8                  -1  1    369792  ultralytics_custom.nn.modules.SPPF           [384, 384, 5]
#   8                  -1  1    369792  ultralytics_custom.nn.modules.SPPF           [384, 384, 5]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 5]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  10             [-1, 5]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  11                  -1  2    517632  ultralytics_custom.nn.modules.C2f            [576, 192, 2]
#  11                  -1  2    517632  ultralytics_custom.nn.modules.C2f            [576, 192, 2]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 3]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  13             [-1, 3]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  14                  -1  2    129792  ultralytics_custom.nn.modules.C2f            [288, 96, 2]
#  14                  -1  2    129792  ultralytics_custom.nn.modules.C2f            [288, 96, 2]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 1]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  16             [-1, 1]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  17                  -1  2     32640  ultralytics_custom.nn.modules.C2f            [144, 48, 2]
#  17                  -1  2     32640  ultralytics_custom.nn.modules.C2f            [144, 48, 2]
#  18                  -1  1     41664  ultralytics_custom.nn.modules.Conv           [48, 96, 3, 2]
#  18                  -1  1     41664  ultralytics_custom.nn.modules.Conv           [48, 96, 3, 2]
#  19            [-1, 14]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  19            [-1, 14]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  20                  -1  2    120576  ultralytics_custom.nn.modules.C2f            [192, 96, 2]
#  20                  -1  2    120576  ultralytics_custom.nn.modules.C2f            [192, 96, 2]
#  21                  -1  1    166272  ultralytics_custom.nn.modules.Conv           [96, 192, 3, 2]
#  21                  -1  1    166272  ultralytics_custom.nn.modules.Conv           [96, 192, 3, 2]
#  22            [-1, 11]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  22            [-1, 11]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  23                  -1  2    480768  ultralytics_custom.nn.modules.C2f            [384, 192, 2]
#  23                  -1  2    480768  ultralytics_custom.nn.modules.C2f            [384, 192, 2]
#  24                  -1  1    664320  ultralytics_custom.nn.modules.Conv           [192, 384, 3, 2]
#  24                  -1  1    664320  ultralytics_custom.nn.modules.Conv           [192, 384, 3, 2]
#  25             [-1, 8]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  25             [-1, 8]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  26                  -1  2   1920000  ultralytics_custom.nn.modules.C2f            [768, 384, 2]
#  26                  -1  2   1920000  ultralytics_custom.nn.modules.C2f            [768, 384, 2]
#  27    [17, 20, 23, 26]  1    975588  ultralytics_custom.nn.modules.Detect         [5, [48, 96, 192, 384]]
#  27    [17, 20, 23, 26]  1    975588  ultralytics_custom.nn.modules.Detect         [5, [48, 96, 192, 384]]
# YOLO_V8_P0-P1 summary: 351 layers, 10482420 parameters, 10482404 gradients, 118.7 GFLOPs
# YOLO_V8_P0-P1 summary: 351 layers, 10482420 parameters, 10482404 gradients, 118.7 GFLOPs
# New https://pypi.org/project/ultralytics/8.3.250 available  Update with 'pip install -U ultralytics'
# New https://pypi.org/project/ultralytics/8.3.250 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.89  Python-3.11.14 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Ultralytics YOLOv8.0.89  Python-3.11.14 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# yolo\engine\trainer: task=detect, mode=train, model=C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\configs\YOLO_V8_P0-P1.yaml, data=C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\data.yaml, epochs=1, patience=100, batch=2, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=yolov8s_1000ep_sgd, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=0, deterministic=False, single_cls=True, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6
# yolo\engine\trainer: task=detect, mode=train, model=C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\configs\YOLO_V8_P0-P1.yaml, data=C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\data.yaml, epochs=1, patience=100, batch=2, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=yolov8s_1000ep_sgd, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=0, deterministic=False, single_cls=True, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6
# WARNING  no model scale passed. Assuming scale='m'.
# WARNING WARNING  no model scale passed. Assuming scale='m'.
#                    from  n    params  module                                       arguments
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics_custom.nn.modules.Conv           [3, 48, 3, 2]
#   0                  -1  1      1392  ultralytics_custom.nn.modules.Conv           [3, 48, 3, 2]
#   1                  -1  1     16416  ultralytics_custom.nn.modules.C2f            [48, 48, 1, True]
#   1                  -1  1     16416  ultralytics_custom.nn.modules.C2f            [48, 48, 1, True]
#   2                  -1  1     41664  ultralytics_custom.nn.modules.Conv           [48, 96, 3, 2]
#   2                  -1  1     41664  ultralytics_custom.nn.modules.Conv           [48, 96, 3, 2]
#   3                  -1  2    111360  ultralytics_custom.nn.modules.C2f            [96, 96, 2, True]
#   3                  -1  2    111360  ultralytics_custom.nn.modules.C2f            [96, 96, 2, True]
#   4                  -1  1    166272  ultralytics_custom.nn.modules.Conv           [96, 192, 3, 2]
#   4                  -1  1    166272  ultralytics_custom.nn.modules.Conv           [96, 192, 3, 2]
#   5                  -1  4    813312  ultralytics_custom.nn.modules.C2f            [192, 192, 4, True]
#   5                  -1  4    813312  ultralytics_custom.nn.modules.C2f            [192, 192, 4, True]
#   6                  -1  1    664320  ultralytics_custom.nn.modules.Conv           [192, 384, 3, 2]
#   6                  -1  1    664320  ultralytics_custom.nn.modules.Conv           [192, 384, 3, 2]
#   7                  -1  4   3248640  ultralytics_custom.nn.modules.C2f            [384, 384, 4, True]
#   7                  -1  4   3248640  ultralytics_custom.nn.modules.C2f            [384, 384, 4, True]
#   8                  -1  1    369792  ultralytics_custom.nn.modules.SPPF           [384, 384, 5]
#   8                  -1  1    369792  ultralytics_custom.nn.modules.SPPF           [384, 384, 5]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 5]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  10             [-1, 5]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  11                  -1  2    517632  ultralytics_custom.nn.modules.C2f            [576, 192, 2]
#  11                  -1  2    517632  ultralytics_custom.nn.modules.C2f            [576, 192, 2]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 3]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  13             [-1, 3]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  14                  -1  2    129792  ultralytics_custom.nn.modules.C2f            [288, 96, 2]
#  14                  -1  2    129792  ultralytics_custom.nn.modules.C2f            [288, 96, 2]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 1]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  16             [-1, 1]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  17                  -1  2     32640  ultralytics_custom.nn.modules.C2f            [144, 48, 2]
#  17                  -1  2     32640  ultralytics_custom.nn.modules.C2f            [144, 48, 2]
#  18                  -1  1     41664  ultralytics_custom.nn.modules.Conv           [48, 96, 3, 2]
#  18                  -1  1     41664  ultralytics_custom.nn.modules.Conv           [48, 96, 3, 2]
#  19            [-1, 14]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  19            [-1, 14]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  20                  -1  2    120576  ultralytics_custom.nn.modules.C2f            [192, 96, 2]
#  20                  -1  2    120576  ultralytics_custom.nn.modules.C2f            [192, 96, 2]
#  21                  -1  1    166272  ultralytics_custom.nn.modules.Conv           [96, 192, 3, 2]
#  21                  -1  1    166272  ultralytics_custom.nn.modules.Conv           [96, 192, 3, 2]
#  22            [-1, 11]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  22            [-1, 11]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  23                  -1  2    480768  ultralytics_custom.nn.modules.C2f            [384, 192, 2]
#  23                  -1  2    480768  ultralytics_custom.nn.modules.C2f            [384, 192, 2]
#  24                  -1  1    664320  ultralytics_custom.nn.modules.Conv           [192, 384, 3, 2]
#  24                  -1  1    664320  ultralytics_custom.nn.modules.Conv           [192, 384, 3, 2]
#  25             [-1, 8]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  25             [-1, 8]  1         0  ultralytics_custom.nn.modules.Concat         [1]
#  26                  -1  2   1920000  ultralytics_custom.nn.modules.C2f            [768, 384, 2]
#  26                  -1  2   1920000  ultralytics_custom.nn.modules.C2f            [768, 384, 2]
#  27    [17, 20, 23, 26]  1    975588  ultralytics_custom.nn.modules.Detect         [5, [48, 96, 192, 384]]
#  27    [17, 20, 23, 26]  1    975588  ultralytics_custom.nn.modules.Detect         [5, [48, 96, 192, 384]]
# YOLO_V8_P0-P1 summary: 351 layers, 10482420 parameters, 10482404 gradients, 118.7 GFLOPs
# YOLO_V8_P0-P1 summary: 351 layers, 10482420 parameters, 10482404 gradients, 118.7 GFLOPs
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\ultralytics_custom\yolo\engine\trainer.py:658: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(True):
# AMP: checks passed
# AMP: checks passed
# c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\ultralytics_custom\yolo\engine\trainer.py:218: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = amp.GradScaler(enabled=self.amp)
# optimizer: SGD(lr=0.01) with parameter groups 91 weight(decay=0.0), 100 weight(decay=0.0005), 99 bias
# optimizer: SGD(lr=0.01) with parameter groups 91 weight(decay=0.0), 100 weight(decay=0.0005), 99 bias
# train: Scanning C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\train\labels.cache... 1727 images, 76 backgrounds, 0 corrupt: 100%|██████████| 1727/1727 [00:00<?, ?it/s]
# val: Scanning C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\valid\labels.cache... 400 images, 24 backgrounds, 1 corrupt: 100%|██████████| 400/400 [00:00<?, ?it/s]
# val: WARNING  C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\valid\images\po_43_jpg.rf.9094062545dc1f1589c39c18ec333c83.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# val: WARNING  C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\valid\images\po_43_jpg.rf.9094062545dc1f1589c39c18ec333c83.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6
# Starting training for 1 epochs...
# No module named 'seaborn'
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6
# Starting training for 1 epochs...
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/864 [00:00<?, ?it/s]c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\ultralytics_custom\yolo\engine\trainer.py:321: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\ultralytics_custom\yolo\utils\loss.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
#         1/1      3.75G      3.419      1.549      3.925          9        640: 100%|██████████| 864/864 [08:15<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 100/100 [00:58<00:00,  1.72it/s]
#                    all        399       2285      0.146      0.248     0.0917     0.0298
#                    all        399       2285      0.146      0.248     0.0917     0.0298
# WARNING  ConfusionMatrix plot failure: No module named 'seaborn'
# 1 epochs completed in 0.156 hours.
# 1 epochs completed in 0.156 hours.
# Optimizer stripped from c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6\weights\last.pt, 22.1MB
# Optimizer stripped from c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6\weights\last.pt, 22.1MB
# Optimizer stripped from c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6\weights\best.pt, 22.1MB
# Optimizer stripped from c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6\weights\best.pt, 22.1MB
# Validating c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6\weights\best.pt...
# Validating c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6\weights\best.pt...
# Ultralytics YOLOv8.0.89  Python-3.11.14 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Ultralytics YOLOv8.0.89  Python-3.11.14 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLO_V8_P0-P1 summary (fused): 260 layers, 10471540 parameters, 0 gradients, 117.6 GFLOPs
# YOLO_V8_P0-P1 summary (fused): 260 layers, 10471540 parameters, 0 gradients, 117.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 100/100 [00:42<00:00,  2.38it/s]
#                    all        399       2285      0.146      0.248     0.0916     0.0298
#                    all        399       2285      0.146      0.248     0.0916     0.0298
#                     PF        399       2285      0.146      0.248     0.0916     0.0298
#                     PF        399       2285      0.146      0.248     0.0916     0.0298
# Speed: 0.7ms preprocess, 65.0ms inference, 0.0ms loss, 12.1ms postprocess per image
# WARNING  ConfusionMatrix plot failure: No module named 'seaborn'
# Speed: 0.7ms preprocess, 65.0ms inference, 0.0ms loss, 12.1ms postprocess per image
# Results saved to c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6
# Results saved to c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd6
# Ultralytics YOLOv8.0.89  Python-3.11.14 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Ultralytics YOLOv8.0.89  Python-3.11.14 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLO_V8_P0-P1 summary (fused): 260 layers, 10471540 parameters, 0 gradients, 117.6 GFLOPs
# YOLO_V8_P0-P1 summary (fused): 260 layers, 10471540 parameters, 0 gradients, 117.6 GFLOPs
# val: Scanning C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\valid\labels.cache... 400 images, 24 backgrounds, 1 corrupt: 100%|██████████| 400/400 [00:00<?, ?it/s]
# val: WARNING  C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\valid\images\po_43_jpg.rf.9094062545dc1f1589c39c18ec333c83.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# val: WARNING  C:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\journal-paper-experiment-1-4\valid\images\po_43_jpg.rf.9094062545dc1f1589c39c18ec333c83.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 399/399 [01:19<00:00,  5.02it/s]
#                    all        399       2285      0.202      0.251      0.119     0.0361
#                    all        399       2285      0.202      0.251      0.119     0.0361
#                     PF        399       2285      0.202      0.251      0.119     0.0361
#                     PF        399       2285      0.202      0.251      0.119     0.0361
# Speed: 1.9ms preprocess, 113.7ms inference, 0.0ms loss, 13.9ms postprocess per image
# WARNING  ConfusionMatrix plot failure: No module named 'seaborn'
# Speed: 1.9ms preprocess, 113.7ms inference, 0.0ms loss, 13.9ms postprocess per image
# Saving c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd7\predictions.json...
# Saving c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd7\predictions.json...
# Results saved to c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd7
# Results saved to c:\Users\Kevin\Desktop\malaria\codes\Malaria_research\yolov8_baseline\ultralytics\Canadia_AI_proposal_Research\runs\detect\yolov8s_1000ep_sgd7
# ultralytics_custom.yolo.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics_custom.yolo.utils.metrics.Metric object
# confusion_matrix: <ultralytics_custom.yolo.utils.metrics.ConfusionMatrix object at 0x0000022A2E798950>
# fitness: np.float64(0.04440782841341348)
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([   0.036126,    0.036126,    0.036126,    0.036126,    0.036126])
# names: {0: 'PF', 1: 'PM', 2: 'PO', 3: 'PV', 4: 'WBC'}
# plot: True
# results_dict: {'metrics/precision(B)': np.float64(0.20150500492523288), 'metrics/recall(B)': np.float64(0.25076586433260395), 'metrics/mAP50(B)': np.float64(0.11894173726283068), 'metrics/mAP50-95(B)': np.float64(0.036126282985700454), 'fitness': np.float64(0.04440782841341348)}
# save_dir: WindowsPath('c:/Users/Kevin/Desktop/malaria/codes/Malaria_research/yolov8_baseline/ultralytics/Canadia_AI_proposal_Research/runs/detect/yolov8s_1000ep_sgd7')
# speed: {'preprocess': 1.9381345065315265, 'inference': 113.72711485191097, 'loss': 0.041834393838294466, 'postprocess': 13.872834375328887}
